# %% [markdown]
# # Analysis
#
# A short notebook whose code cell renders a plot.

# %%
print('replace through fallback')
# Out:
# stale fallback output

# %%
print('training complete')
# Out:
# training complete

# %%
fig

# %% [raw]
# RAW_CELL_SENTINEL
# Preserve this source representation.

# %%
raise FixtureError('STABLE_ERROR_VALUE')
# Out:
# Traceback (most recent call last):
#   <fixture traceback sentinel>
# FixtureError: STABLE_ERROR_VALUE
